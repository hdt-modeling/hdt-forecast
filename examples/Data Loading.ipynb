# %% [markdown]
# # Overview
#
# We build data loaders for general use as well as model-specific ones. In this notebook you will see how to use them to request data.

# %%
from hdt_util import Basic_feeder, ArmadilloV1_feeder
import datetime

# %% [markdown]
# ## Data Loader for General Use
#
# You can get data about:
#
#     1. confirmed cases from `jhu-csse` database or `usa-facts` database
#     2. death cases from `jhu-csse` database or `usa-facts` database
#     3. mobility data from `safegraph` database
#     4. leading indicators from `fb-survey` database or `doctor-visits` database

# %%
loader = Basic_feeder('./request_cache')

# %% [markdown]
# ## get state level confirmed cases from jhu-csse in October

# %%
loader.query_cases(source='jhu-csse', 
                   signal='confirmed', 
                   start_date=datetime.date(2020, 10, 1),
                   end_date=datetime.date(2020, 10, 31), 
                   level='state', 
                   count=True, 
                   cumulated=False)
# Out:
#    geo_value                   signal time_value      issue  lag  value  \
# 0         ak  confirmed_incidence_num 2020-10-01 2020-10-30   29    140
# 1         al  confirmed_incidence_num 2020-10-01 2020-10-14   13   1043
# 2         ar  confirmed_incidence_num 2020-10-01 2020-10-14   13   1124
# 3         az  confirmed_incidence_num 2020-10-01 2020-10-14   13    705
# 4         ca  confirmed_incidence_num 2020-10-01 2020-10-14   13   3090
# ..       ...                      ...        ...        ...  ...    ...
# 47        vt  confirmed_incidence_num 2020-10-30 2020-10-31    1     14
# 48        wa  confirmed_incidence_num 2020-10-30 2020-10-31    1   1016
# 49        wi  confirmed_incidence_num 2020-10-30 2020-10-31    1   5096
# 50        wv  confirmed_incidence_num 2020-10-30 2020-10-31    1    526
# 51        wy  confirmed_incidence_num 2020-10-30 2020-10-31    1    521
#
#    stderr sample_size geo_type data_source
# 0    None        None    state    jhu-csse
# 1    None        None    state    jhu-csse
# 2    None        None    state    jhu-csse
# 3    None        None    state    jhu-csse
# 4    None        None    state    jhu-csse
# ..    ...         ...      ...         ...
# 47   None        None    state    jhu-csse
# 48   None        None    state    jhu-csse
# 49   None        None    state    jhu-csse
# 50   None        None    state    jhu-csse
# 51   None        None    state    jhu-csse
#
# [1560 rows x 10 columns]

# %% [markdown]
# ## get county level death cases from usa-facts in November

# %%
loader.query_cases(source='usa-facts', 
                   signal='deaths', 
                   start_date=datetime.date(2020, 11, 1),
                   end_date=datetime.date(2020, 11, 30), 
                   level='county', 
                   count=True, 
                   cumulated=False)
# Out:
#      geo_value                signal time_value      issue  lag  value stderr  \
# 0        01000  deaths_incidence_num 2020-11-01 2020-11-03    2    0.0   None
# 1        01001  deaths_incidence_num 2020-11-01 2020-11-03    2    0.0   None
# 2        01003  deaths_incidence_num 2020-11-01 2020-11-03    2    0.0   None
# 3        01005  deaths_incidence_num 2020-11-01 2020-11-03    2    0.0   None
# 4        01007  deaths_incidence_num 2020-11-01 2020-11-03    2    0.0   None
# ...        ...                   ...        ...        ...  ...    ...    ...
# 3187     56037  deaths_incidence_num 2020-11-29 2020-11-30    1    0.0   None
# 3188     56039  deaths_incidence_num 2020-11-29 2020-11-30    1    0.0   None
# 3189     56041  deaths_incidence_num 2020-11-29 2020-11-30    1    0.0   None
# 3190     56043  deaths_incidence_num 2020-11-29 2020-11-30    1    0.0   None
# 3191     56045  deaths_incidence_num 2020-11-29 2020-11-30    1    0.0   None
#
#      sample_size geo_type data_source
# 0           None   county   usa-facts
# 1           None   county   usa-facts
# 2           None   county   usa-facts
# 3           None   county   usa-facts
# 4           None   county   usa-facts
# ...          ...      ...         ...
# 3187        None   county   usa-facts
# 3188        None   county   usa-facts
# 3189        None   county   usa-facts
# 3190        None   county   usa-facts
# 3191        None   county   usa-facts
#
# [92568 rows x 10 columns]

# %% [markdown]
# ## get state level mobility data from safegraph for September with different signals

# %%
loader.query_mobility(signal=1, 
                      start_date=datetime.date(2020, 9, 1), 
                      end_date=datetime.date(2020, 9, 30), 
                      level='state')
# Out:
#    geo_value                signal time_value      issue  lag     value  \
# 0         ak  completely_home_prop 2020-09-01 2020-09-30   29  0.213540
# 1         al  completely_home_prop 2020-09-01 2020-09-30   29  0.193800
# 2         ar  completely_home_prop 2020-09-01 2020-09-30   29  0.205252
# 3         as  completely_home_prop 2020-09-01 2020-09-30   29  0.379461
# 4         az  completely_home_prop 2020-09-01 2020-09-30   29  0.285534
# ..       ...                   ...        ...        ...  ...       ...
# 49        vt  completely_home_prop 2020-09-26 2020-09-30    4  0.261621
# 50        wa  completely_home_prop 2020-09-26 2020-09-30    4  0.318655
# 51        wi  completely_home_prop 2020-09-26 2020-09-30    4  0.265433
# 52        wv  completely_home_prop 2020-09-26 2020-09-30    4  0.263010
# 53        wy  completely_home_prop 2020-09-26 2020-09-30    4  0.269760
#
#       stderr  sample_size geo_type data_source
# 0   0.004175          519    state   safegraph
# 1   0.001156         3434    state   safegraph
# 2   0.001458         2139    state   safegraph
# 3   0.087716            6    state   safegraph
# 4   0.001290         4153    state   safegraph
# ..       ...          ...      ...         ...
# 49  0.004402          522    state   safegraph
# 50  0.001315         4768    state   safegraph
# 51  0.001271         4475    state   safegraph
# 52  0.002251         1588    state   safegraph
# 53  0.004211          410    state   safegraph
#
# [1445 rows x 10 columns]

# %%
loader.query_mobility(signal=2, 
                      start_date=datetime.date(2020, 9, 1), 
                      end_date=datetime.date(2020, 9, 30), 
                      level='state')
# Out:
#    geo_value               signal time_value      issue  lag     value  \
# 0         ak  full_time_work_prop 2020-09-01 2020-09-30   29  0.048815
# 1         al  full_time_work_prop 2020-09-01 2020-09-30   29  0.068018
# 2         ar  full_time_work_prop 2020-09-01 2020-09-30   29  0.068502
# 3         as  full_time_work_prop 2020-09-01 2020-09-30   29  0.119384
# 4         az  full_time_work_prop 2020-09-01 2020-09-30   29  0.042552
# ..       ...                  ...        ...        ...  ...       ...
# 49        vt  full_time_work_prop 2020-09-26 2020-09-30    4  0.036295
# 50        wa  full_time_work_prop 2020-09-26 2020-09-30    4  0.029936
# 51        wi  full_time_work_prop 2020-09-26 2020-09-30    4  0.027789
# 52        wv  full_time_work_prop 2020-09-26 2020-09-30    4  0.030007
# 53        wy  full_time_work_prop 2020-09-26 2020-09-30    4  0.034870
#
#       stderr  sample_size geo_type data_source
# 0   0.001470          519    state   safegraph
# 1   0.000621         3434    state   safegraph
# 2   0.000787         2139    state   safegraph
# 3   0.018801            6    state   safegraph
# 4   0.000420         4153    state   safegraph
# ..       ...          ...      ...         ...
# 49  0.001153          522    state   safegraph
# 50  0.000313         4768    state   safegraph
# 51  0.000308         4475    state   safegraph
# 52  0.000537         1588    state   safegraph
# 53  0.001271          410    state   safegraph
#
# [1445 rows x 10 columns]

# %% [markdown]
# ## get county leading indicator data from facebook in November

# %%
loader.query_leading_indicator(source='fb-survey', 
                               signal='smoothed_cli', 
                               start_date=datetime.date(2020, 11, 1), 
                               end_date=datetime.date(2020, 11, 30), 
                               level='county')
# Out:
#     geo_value        signal time_value      issue  lag     value    stderr  \
# 0       01000  smoothed_cli 2020-11-01 2020-11-06    5  1.092908  0.199894
# 1       01003  smoothed_cli 2020-11-01 2020-11-06    5  0.728908  0.659655
# 2       01073  smoothed_cli 2020-11-01 2020-11-06    5  0.947050  0.501025
# 3       01089  smoothed_cli 2020-11-01 2020-11-06    5  1.335795  0.581266
# 4       01097  smoothed_cli 2020-11-01 2020-11-06    5  0.960620  0.561501
# ..        ...           ...        ...        ...  ...       ...       ...
# 655     55139  smoothed_cli 2020-11-29 2020-11-30    1  1.610003  0.775597
# 656     55141  smoothed_cli 2020-11-29 2020-11-30    1  0.497576  0.620701
# 657     56000  smoothed_cli 2020-11-29 2020-11-30    1  2.214070  0.506224
# 658     56021  smoothed_cli 2020-11-29 2020-11-30    1  2.583695  1.170287
# 659     56025  smoothed_cli 2020-11-29 2020-11-30    1  2.001629  0.904148
#
#      sample_size geo_type data_source
# 0      1209.3305   county   fb-survey
# 1       171.0638   county   fb-survey
# 2       204.1320   county   fb-survey
# 3       365.9611   county   fb-survey
# 4       237.9386   county   fb-survey
# ..           ...      ...         ...
# 655     234.5825   county   fb-survey
# 656     115.6976   county   fb-survey
# 657     486.1960   county   fb-survey
# 658     159.9764   county   fb-survey
# 659     131.8587   county   fb-survey
#
# [16664 rows x 10 columns]

# %% [markdown]
# # Load data for ArmadilloV1

# %%
loader = ArmadilloV1_feeder('./request_cache')

# %%
#load raw data
data = loader.get_data(source='jhu-csse', 
                       signal='deaths', 
                       start_date=datetime.date(2020, 5, 1),
                       end_date=datetime.date(2020, 8, 1), 
                       level='county', 
                       count=True, 
                       cumulated=False,
                       mobility_level=1)
data.head()
# Out:
#   geo_value       date  case_value  time  dayofweek  mobility_value
# 0     01001 2020-05-01          -1    62          4        0.223168
# 1     01003 2020-05-01           1    62          4        0.253409
# 2     01005 2020-05-01           0    62          4        0.219235
# 3     01007 2020-05-01           0    62          4        0.206663
# 4     01009 2020-05-01           0    62          4        0.209368

# %%
data.tail()
# Out:
#        geo_value       date  case_value  time  dayofweek  mobility_value
# 279561     56037 2020-07-28           0   150          1        0.246500
# 279562     56039 2020-07-28           0   150          1        0.230085
# 279563     56041 2020-07-28           0   150          1        0.282966
# 279564     56043 2020-07-28           0   150          1        0.274957
# 279565     56045 2020-07-28           0   150          1        0.287944

# %%
#filter data to Yolo
filtered_data = loader.area_filter(input=data,
                                   area=['06113'])
filtered_data.head()
# Out:
#   geo_value       date  case_value  time  dayofweek  mobility_value
# 0     06113 2020-05-01           0    62          4        0.430326
# 1     06113 2020-05-02           0    63          5        0.428025
# 2     06113 2020-05-03           1    64          6        0.421607
# 3     06113 2020-05-04           2    65          0        0.421030
# 4     06113 2020-05-05           0    66          1        0.432966

# %%
filtered_data.tail()
# Out:
#    geo_value       date  case_value  time  dayofweek  mobility_value
# 84     06113 2020-07-24           0   146          4        0.301759
# 85     06113 2020-07-25           0   147          5        0.350235
# 86     06113 2020-07-26           0   148          6        0.373460
# 87     06113 2020-07-27           0   149          0        0.341095
# 88     06113 2020-07-28           2   150          1        0.322936

# %%
#summarize data for weeks
weekly_data = loader.pooling(input=filtered_data,
                             period=7,
                             end_date=datetime.date(2020, 8, 10))

# %%
weekly_data.tail()
# Out:
#    geo_value  time  case_value  mobility_value
# 9      06113     9         2.0        0.344165
# 10     06113    10         6.0        0.345335
# 11     06113    11         3.0        0.340534
# 12     06113    12         2.0        0.322936
# 13     06113    13         0.0        0.322936

# %%
args = {'M':avg_temp_train['mobility_value'].values,
                    'DC':DC,
                    'y_true':avg_temp_train['case_value'].values}
            
            model.fit(args)
